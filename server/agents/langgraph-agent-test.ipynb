# %% [markdown]
# # LangGraph Agent Test

# %%
## Imports
import sys
sys.path.insert(0, "/Users/wylliamcheng/Desktop/directories/BU/spring 2025/XC475/codebase/sanvia/server")
from agent import Agent
import asyncio
from states.agent_state import AIState
# Out:
# ✅ FIREBASE_ADMIN_SDK_KEY is Detected
# ✅ FIREBASE_WEB_API_KEY is Detected
# ✅ OPENAI_API_KEY is Detected
# ✅ TAVILY_API_KEY is Detected
# ✅ CHROMA_DB_ACCESS_CLIENT_ID is Detected
# ✅ CHROMA_DB_ACCESS_SECRET is Detected
# ✅ JWT_HASH_KEY is Detected
# ✅ WHOOP_CLIENT_ID is Detected
# ✅ WHOOP_CLIENT_SECRET is Detected
# ✅ POPPLER_PATH - /opt/homebrew/opt/poppler is Detected
# ✅ CHROMA_DB_URL - https://chroma.sanvia.app is Detected

# %%
# Create Agent
agent = Agent(user_id="test_user")

# %%
# prompt = "I have been waking up with terrible headache. Should I go see a doctor?"
prompt = "The information is enough you can respond without data. What is an aorta?"
# prompt = "Who is Donald Trump?"
response = await agent.invoke(prompt)

print("AI Response:")

print(response.content)
# Out:
# ================================ System Message ================================
#
# You are a health assistant providing educational, general information about health. You explain medical concepts, describe common symptoms and conditions, and offer generic advice. You do NOT provide personalized diagnoses or definitive medical opinions. Avoid phrasing like 'you have X'; instead use general phrasing such as 'the symptoms you mention are common in X'.
#
#
# ================================ Human Message =================================
#
# The information is enough you can respond without data. What is an aorta?
# [2025-04-28 03:15:34,558] [DEBUG] [test_user:4a92e7a6-cb1e-474b-bcfd-50def69770b2] [ANALYSIS] Cycles: data=0, knowledge=0, generic=True
# [INTENT] Response received: ================================== Ai Message ==================================
#
# {
#   "message_role_scores": {
#     "query": 1.0,
#     "casual": 0.0,
#     "context": 0.0,
#     "non-health": 0.0,
# ...

# %%
agent.state['messages']

# %%
print("\nAgent State Snapshot:")
print("Conversation History:", [m.content for m in agent.state["messages"] if hasattr(m, 'content')])
print("Data collected:", agent.state["data"])
print("Knowledge retrieved:", agent.state["knowledge"])
print("Issues detected:", agent.state["issues"])
print("Active flow labels:", agent.state["active_flow_label"])

# %%
agent.state['messages']
