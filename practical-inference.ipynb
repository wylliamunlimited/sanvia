# %% [markdown]
# ## Inference

# %%
import sys

# caution: path[0] is reserved for script path (or '' in REPL)
# sys.path.insert(1, "./server/dependencies")
# sys.path.insert(2, "./server/constants")
# sys.path.insert(3, "./server/routers")
# sys.path.insert(4, "./server")

print("\n".join(sys.path))
from server.agents.agent import Agent
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python310.zip
# ../dependencies
# ../constants
# ../routers
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/lib-dynload
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/codellama-0.0.1-py3.10.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/sentencepiece-0.2.0-py3.10-macosx-11.0-arm64.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/fire-0.6.0-py3.10.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/fairscale-0.4.13-py3.10.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/termcolor-2.4.0-py3.10.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/fsspec-2024.3.1-py3.10.egg
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/setuptools/_vendor
# ...
